# %%
import pandas as pd

# Load the dataset
file_path = '/content/globalterrorismdb_0718dist.csv'  # Update if needed
terrorism_data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Basic information about the dataset
terrorism_data.info()

# Display the first few rows
terrorism_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34563 entries, 0 to 34562
# Columns: 135 entries, eventid to related
# dtypes: float64(57), int64(21), object(57)
# memory usage: 35.6+ MB
# <ipython-input-1-b75afe7a68ca>:5: DtypeWarning: Columns (4,31,33,53,61,62,76,79,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terrorism_data = pd.read_csv(file_path, encoding='ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# ...

# %%
# Check for missing values
missing_values = terrorism_data.isnull().sum()

# Display columns with missing values
missing_values[missing_values > 0]
# Out:
# approxdate    34540
# resolution    33984
# provstate       131
# latitude       1886
# longitude      1886
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       31515
# Length: 106, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the number of attacks per year
plt.figure(figsize=(10,6))
sns.countplot(x='iyear', data=terrorism_data, palette='viridis')
plt.xticks(rotation=90)
plt.title('Number of Terrorist Attacks per Year')
plt.show()

# Top 10 countries with the most attacks
top_countries = terrorism_data['country_txt'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.index, y=top_countries.values, palette='inferno')
plt.title('Top 10 Countries with the Most Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-3-08c23ef62b60>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='iyear', data=terrorism_data, palette='viridis')
# <ipython-input-3-08c23ef62b60>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.index, y=top_countries.values, palette='inferno')

# %%
# Hot zones by region
hot_zones_region = terrorism_data['region_txt'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=hot_zones_region.index, y=hot_zones_region.values, palette='coolwarm')
plt.title('Regions with the Most Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-4-8e3bdbe1c159>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hot_zones_region.index, y=hot_zones_region.values, palette='coolwarm')

# %%
# Common attack types
attack_types = terrorism_data['attacktype1_txt'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=attack_types.index, y=attack_types.values, palette='magma')
plt.title('Most Common Types of Terrorist Attacks')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-5-1e402bef8eb4>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attack_types.index, y=attack_types.values, palette='magma')
